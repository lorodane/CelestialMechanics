# %% [markdown]
# # Experiment Prototype Title

# %%
import numpy as np
import matplotlib.pyplot as plt

from src.utils.plotting import polar_scatter

# %%
theta = np.linspace(0, 2 * np.pi, 100)
r = np.abs(np.sin(3 * theta))  # Example function for radius


fig, ax = polar_scatter(theta, r)
ax.set_title('Polar Scatter Plot')
ax.legend(['r = |sin(3θ)|'])
plt.show()

# %%
from pathlib import Path
from src.utils.plotting import save_figure

saved_path = save_figure(fig = fig, name = "stable_islands_example", folder_path="plots")
print(saved_path)
# Out:
# ---------------------------------------------------------------------------
# FileExistsError                           Traceback (most recent call last)
# Cell In[4], line 4
#       1 from pathlib import Path
#       2 from src.utils.plotting import save_figure
# ----> 4 saved_path = save_figure(fig = fig, name = "stable_islands_example", folder_path="plots")
#       5 print(saved_path)
#
# File ~\Desktop\TFG\CelestialMechanics\sitnikov\src\utils\plotting.py:25, in save_figure(fig, name, folder_path, dpi, bbox_inches, extension)
#      22 save_path = folder / f"{name}.{extension}"
#      24 if save_path.exists():
# ---> 25     raise FileExistsError(f"Figure already exists at {save_path}")
#      27 fig.savefig(save_path, dpi=dpi, bbox_inches=bbox_inches)
#      28 return save_path
#
# FileExistsError: Figure already exists at plots\stable_islands_example.png
